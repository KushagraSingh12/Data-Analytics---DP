# %%
fruits = [ 'apple','mango','banana', 'litchi','watermelon','kiwi']
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'litchi', 'watermelon', 'kiwi']

# %%
fruits = [ 'apple','mango','banana', 'litchi','watermelon','kiwi']
for el in fruits: 
  print(el)
# Out:
# apple
# mango
# banana
# litchi
# watermelon
# kiwi

# %%
to print the whole list we only use collen(:)

# %%
print(fruits[0])
print(fruits[:])
print(fruits[0:5:2])
# Out:
# apple
# ['apple', 'mango', 'banana', 'litchi', 'watermelon', 'kiwi']
# ['apple', 'banana', 'watermelon']

# %%
print(fruits[-1])
print(fruits[-6])
# Out:
# kiwi
# apple

# %%
print(fruits[-2:])
print(fruits[:-2])
# Out:
# ['watermelon', 'kiwi']
# ['apple', 'mango', 'banana', 'litchi']

# %%
fruits.append('guvava')
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'litchi', 'watermelon', 'kiwi', 'guvava']

# %%
fruits.pop(-2,)
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'litchi', 'watermelon', 'dragonfruit', 'guvava']

# %%
fruits.insert(-2,'allo')
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'litchi', 'watermelon', 'allo', 'dragonfruit', 'guvava']

# %%
fruits.remove('mango')
print(fruits)
# Out:
# ['apple', 'banana', 'litchi', 'watermelon', 'allo', 'dragonfruit', 'guvava']

# %%
a = fruits.copy()
print(a)
# Out:
# ['apple', 'banana', 'litchi', 'watermelon', 'allo', 'dragonfruit', 'guvava']

# %%
a.clear()
print(a)
# Out:
# []

# %%
fruits.sort()
print(fruits)
# Out:
# ['allo', 'apple', 'banana', 'dragonfruit', 'guvava', 'litchi', 'watermelon']

# %%
fruits2= [1,2,3,4,5,6]
fruits.extend(fruits2)
print(fruits)
# Out:
# ['allo', 'apple', 'banana', 'dragonfruit', 'guvava', 'litchi', 'watermelon', 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %%
fruits2.extend(fruits)
print(fruits2)
# Out:
# [1, 2, 3, 4, 5, 6, 'allo', 'apple', 'banana', 'dragonfruit', 'guvava', 'litchi', 'watermelon', 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 'allo', 'apple', 'banana', 'dragonfruit', 'guvava', 'litchi', 'watermelon', 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]
