# %%
name = "Alice"
print(name)
# Out:
# Alice

# %%
#string concatenation
a = 'hello'
b = 'world'
print(a+' '+b)
# Out:
# hello world

# %%
#string duplication 
a = 'hey'
print(a*10)
# Out:
# heyheyheyheyheyheyheyheyheyhey

# %%
x = 'beautiful'
x.upper()
# Out:
# 'BEAUTIFUL'

# %%
x.lower()
# Out:
# 'beautiful'

# %%
x.capitalize()
# Out:
# 'Beautiful'

# %%
y=' all the best'
y.title()
# Out:
# ' All The Best'

# %%
#multiline string 
poem = ''' johny johny yes papa 
eating sugar no papa 
tellin a lie no papa
open your mouth hahahaa'''
print(poem)
# Out:
#  johny johny yes papa
# eating sugar no papa
# tellin a lie no papa
# open your mouth hahahaa

# %%
poem.find('papa')
# Out:
# 17

# %%
p = poem.replace('papa','fufa')
print(p)
# Out:
#  johny johny yes fufa
# eating sugar no fufa
# tellin a lie no fufa
# open your mouth hahahaa

# %%
p = poem.replace('papa','fufa'). replace('sugar','poison').replace('yes','no').replace('hahahaa','bhkk')
print(p)
# Out:
#  johny johny no fufa
# eating poison no fufa
# tellin a lie no fufa
# open your mouth bhkk

# %%
print(y)
# Out:
#  all the best

# %%
y.split()
# Out:
# ['all', 'the', 'best']

# %%
p.splitlines()
# Out:
# [' johny johny no fufa ',
#  'eating poison no fufa ',
#  'tellin a lie no fufa',
#  'open your mouth bhkk']
